# %%
import process_corpus
import mwu_functions
from importlib import reload
mwu_functions = reload(mwu_functions)

# %%
process_corpus.process_corpus(corpus='bnc', corpus_dir='bnc_tokenized.txt', verbose=True, chunk_size = 500000)
# Out:
# Preprocessing the corpus
# Reading and cleaning corpus...
# 3865 lines processed
# 7861 lines processed
# 12081 lines processed
# 17472 lines processed
# 22156 lines processed
# 26169 lines processed
# 30388 lines processed
# 35246 lines processed
# 39496 lines processed
# 44544 lines processed
# 49054 lines processed
# 53278 lines processed
# 57709 lines processed
# 61338 lines processed
# 65932 lines processed
# 71974 lines processed
# 76745 lines processed
# 79987 lines processed
# 84505 lines processed
# 88081 lines processed
# 93794 lines processed
# 97778 lines processed
# 100717 lines processed
# 104417 lines processed
# 108420 lines processed
# 112954 lines processed
# 118388 lines processed
# 123989 lines processed
# 128383 lines processed
# 133189 lines processed
# 137597 lines processed
# 142741 lines processed
# 147682 lines processed
# 151667 lines processed
# 157484 lines processed
# 162135 lines processed
# 166758 lines processed
# 170976 lines processed
# ...

# %%
mwu_functions.get_mwu_scores(["i don't", 'i care', 'i go', 'you go', "they don't", "the highway", "long highway"])
# Out:
# i don't
# 0
# i care
# 1
# i go
# 2
# you go
# 3
# they don't
# 4
# the highway
# 5
# /home/pablo/Documents/GitHub/MWU_measures/compute_functions.py:21: RuntimeWarning: divide by zero encountered in log2
#   info = np.log2(ratios)
# /home/pablo/Documents/GitHub/MWU_measures/compute_functions.py:21: RuntimeWarning: divide by zero encountered in log2
#   info = np.log2(ratios)
# long highway
# 6
# ngram long highway is not in the corpus
#           ngram first   second  token_freq  dispersion  type_1  type_2  \
# 0       i don't     i    don't       37196    0.657879    4249    8451
# 1        i care     i     care         200    0.840979    1526    8451
# 2          i go     i       go        2265    0.699932    3610    8451
# 3        you go   you       go        5189    0.606254    3610   10010
# 4    they don't  they    don't        4775    0.709081    4249    7511
# 5   the highway   the  highway         358    0.951389     232  154283
# ...

# %%
#TODO: Documentation
#TODO: Normalization
#TODO: Division by zero in log2
#TODO: Scale to trigrams
#TODO: memory profiling
#TODO: Simplify selection of chunk size in reading corpus
